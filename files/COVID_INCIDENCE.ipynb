# %%
import requests
from bs4 import BeautifulSoup
from urllib import request 
import zipfile
import pandas as pd
from pandas import Timestamp
import matplotlib.pyplot as plt
import plotnine as pn
import numpy as np
import datetime as dt

# %%
URL = 'https://covid19.ssi.dk/overvagningsdata/download-fil-med-overvaagningdata'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser')

# %%
latest_link = soup.find('blockquote').find('a')['href']

# %%
latest_link
# Out:
# 'https://files.ssi.dk/covid19/overvagning/data/data-epidemiologiske-rapport-25022021-1us0'

# %%
filehandle, _ = request.urlretrieve(latest_link)

# %%
zip_file_object = zipfile.ZipFile(filehandle, 'r')

# %%
zip_file_object.namelist()
# Out:
# ['0_read_me.txt',
#  'Cases_by_age.csv',
#  'Cases_by_sex.csv',
#  'Deaths_over_time.csv',
#  'Municipality_cases_time_series.csv',
#  'Municipality_tested_persons_time_series.csv',
#  'Municipality_test_pos.csv',
#  'Newly_admitted_over_time.csv',
#  'Region_summary.csv',
#  'Rt_cases_2021_02_23.csv',
#  'Test_pos_over_time.csv',
#  'Test_regioner.csv']

# %%
zip_Test_pos_over_time = zip_file_object.open('Test_pos_over_time.csv')
zip_Newly_admitted_over_time = zip_file_object.open('Newly_admitted_over_time.csv')
zip_Deaths_over_time = zip_file_object.open('Deaths_over_time.csv')

# %%
df_Test_pos_over_time = pd.read_csv(zip_Test_pos_over_time,sep=";",skipfooter=4,parse_dates=True, thousands='.')
df_Newly_admitted_over_time = pd.read_csv(zip_Newly_admitted_over_time,skipfooter=1,sep=";",parse_dates=True, thousands='.')
df_Deaths_over_time = pd.read_csv(zip_Deaths_over_time,sep=";",skipfooter=3,parse_dates=True, thousands='.')

# %% [markdown]
# # Tests over time

# %%
df_Test_pos_over_time.head(5)
# Out:
#          Date  NewPositive  NotPrevPos PosPct  PrevPos  Tested  \
# 0  2020-01-27            0           0    0,0        0       0
# 1  2020-01-28            0           0    0,0        0       0
# 2  2020-01-29            0           0    0,0        0       0
# 3  2020-01-30            0           0    0,0        0       0
# 4  2020-01-31            0           0    0,0        0       0
#
#    Tested_kumulativ
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
(
    pn.ggplot(df_Test_pos_over_time, pn.aes('Date', 'NewPositive'))
 + pn.geom_point() 
 + pn.geom_smooth()
 + pn.scale_x_date(date_breaks='2 months',date_labels="%Y-%m")
 + pn.theme_bw() 
 + pn.labs(x="Dato",y="Nye Tilfælde")
 )
# Out:
# <ggplot: (153636808015)>

# %% [markdown]
# ## 14 day incidence

# %%
df_Test_pos_over_time["14DayIncidence"] = df_Test_pos_over_time.NewPositive.rolling(14).sum()/5793636*100000

# %%
(
    pn.ggplot(df_Test_pos_over_time,pn.aes(x="Date",y="14DayIncidence")) 
    + pn.geom_point() 
    + pn.scale_x_date(date_breaks="1 months") 
    + pn.theme_bw()
    + pn.theme(axis_text_x=pn.element_text(angle=45,hjust=1))
)
# Out:
# <ggplot: (153636808045)>

# %% [markdown]
# ## Regression exponential

# %%
df_regression = df_Test_pos_over_time[df_Test_pos_over_time["Date"]>"2020-12-22"]

x = pd.to_datetime(df_regression['Date'])
x = x.map(dt.datetime.toordinal)
y = np.log(df_regression.NewPositive)

fit_exp = np.polyfit(x,y,1, cov=True)

# %%
ordinals = np.arange(start = max(x),stop = max(x) + 90)
date_range = pd.date_range(dt.datetime.today(),periods=90)
pred = np.exp(np.polyval(fit_exp[0],ordinals))
lwr = np.exp(np.polyval(fit_exp[1][0],ordinals))
upr = np.exp(np.polyval(fit_exp[1][1],ordinals))

# %%
pn.ggplot(pn.aes(x=date_range,y=pred)) + pn.geom_point()
# Out:
# <ggplot: (153636902123)>

# %%
plt.clf()
plt.scatter(x = date_range, y = pred)
plt.fill_between(x = date_range, y1 = lwr, y2 = upr)
plt.show()

# %%
datelist = pd.Series(pd.date_range(dt.datetime.today(),periods=90))
dates = np.polyval(fit_exp,datelist.apply(lambda x: x.toordinal()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-b1909c7deed8> in <module>
#       1 datelist = pd.Series(pd.date_range(dt.datetime.today(),periods=90))
# ----> 2 dates = np.polyval(fit_exp,datelist.apply(lambda x: x.toordinal()))
#
# <__array_function__ internals> in polyval(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\polynomial.py in polyval(p, x)
#     725
#     726     """
# --> 727     p = NX.asarray(p)
#     728     if isinstance(x, poly1d):
#     729         y = 0
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not broadcast input array from shape (2,2) into shape (2)

# %% [markdown]
# # Rt calculation

# %%
import covsirphy as cs
# Download and update datasets
data_loader = cs.DataLoader("input")
jhu_data = data_loader.jhu()
population_data = data_loader.population()
# Check records
snl = cs.Scenario(jhu_data, population_data, country="Denmark")
# Out:
# Retrieving datasets from COVID-19 Data Hub: https://covid19datahub.io/
#
# Please set verbose=2 to see the detailed citation list.
#
#
# Retrieving COVID-19 dataset in Japan from https://github.com/lisphilar/covid19-sir/data/japan
#           Date  Infected  Fatal  Recovered
# 0   2020-03-06        22      0          1
# 1   2020-03-07        22      0          1
# 2   2020-03-08        34      0          1
# 3   2020-03-09        89      0          1
# 4   2020-03-10       222      0         40
# ..         ...       ...    ...        ...
# 351 2021-02-20      5722   2333     199026
# 352 2021-02-21      5790   2338     199449
# 353 2021-02-22      5866   2343     199818
# 354 2021-02-23      5950   2343     200263
# 355 2021-02-24      5950   2343     200263
#
# [356 rows x 4 columns]

# %%
complement_snl_df = snl.show_complement()
complement_snl_df.tail()
# Out:
#    Country Province Monotonic_confirmed Monotonic_fatal Monotonic_recovered  \
# 0  Denmark        -               False            True               False
#
#   Full_recovered Partial_recovered
# 0          False              True

# %%
# Parameter estimation of SIR-F model
snl.estimate(cs.SIRF)
# Out:
# ---------------------------------------------------------------------------
# UnExecutedError                           Traceback (most recent call last)
# <ipython-input-22-2122648c4f78> in <module>
#       1 # Parameter estimation of SIR-F model
# ----> 2 snl.estimate(cs.SIRF)
#
# ~\anaconda3\lib\site-packages\covsirphy\analysis\scenario.py in estimate(self, model, phases, name, n_jobs, **kwargs)
#     447             raise ValueError(
#     448                 "@tau must be specified when scenario = Scenario(), and cannot be specified here.")
# --> 449         self.tau, self[name] = self._tracker(name).estimate(
#     450             model=model, phases=phases, n_jobs=n_jobs, **kwargs)
#     451
#
# ~\anaconda3\lib\site-packages\covsirphy\analysis\param_tracker.py in estimate(self, model, phases, n_jobs, **kwargs)
#     405             - In kwargs, tau value cannot be included.
#     406         """
# --> 407         self._ensure_phase_setting()
#     408         model = self.ensure_subclass(model, ModelBase, "model")
#     409         units = [
#
# ~\anaconda3\lib\site-packages\covsirphy\analysis\param_tracker.py in _ensure_phase_setting(self)
#     106         """
#     107         if not self._series:
# --> 108             raise UnExecutedError(".trend() or .add()")
#     109
#     110     def find_phase(self, date):
#
# UnExecutedError: Please execute .trend() or .add() in advance.

# %%
snl.trend(set_phases=True)
snl.summary()
# Out:
#       Type      Start        End  Population
# 0th   Past  06Mar2020  17Apr2020     5793636
# 1st   Past  18Apr2020  06Aug2020     5793636
# 2nd   Past  07Aug2020  17Sep2020     5793636
# 3rd   Past  18Sep2020  06Oct2020     5793636
# 4th   Past  07Oct2020  24Oct2020     5793636
# 5th   Past  25Oct2020  04Nov2020     5793636
# 6th   Past  05Nov2020  15Nov2020     5793636
# 7th   Past  16Nov2020  25Nov2020     5793636
# 8th   Past  26Nov2020  04Dec2020     5793636
# 9th   Past  05Dec2020  10Dec2020     5793636
# 10th  Past  11Dec2020  16Dec2020     5793636
# 11th  Past  17Dec2020  22Dec2020     5793636
# 12th  Past  23Dec2020  28Dec2020     5793636
# 13th  Past  29Dec2020  05Jan2021     5793636
# 14th  Past  06Jan2021  15Jan2021     5793636
# 15th  Past  16Jan2021  31Jan2021     5793636
# 16th  Past  01Feb2021  24Feb2021     5793636

# %%
# Estimate the parameter values of SIR-F model
# Default value of timeout is 180 sec
snl.estimate(cs.SIRF, timeout=60)
# Out:
# <SIR-F model: parameter estimation>
# Running optimization with 8 CPUs...
# 	15th phase (06Jan2021 - 15Jan2021): finished  937 trials in 0 min 40 sec
# Completed optimization. Total: 2 min 28 sec

# %%
# Show the sumamry of parameter estimation
snl.summary()
# Out:
#       Type      Start        End  Population    ODE    Rt     theta     kappa  \
# 0th   Past  06Mar2020  17Apr2020     5793636  SIR-F  3.76  0.085758  0.000243
# 1st   Past  18Apr2020  06Aug2020     5793636  SIR-F  0.70  0.036083  0.000560
# 2nd   Past  07Aug2020  17Sep2020     5793636  SIR-F  1.36  0.000664  0.000255
# 3rd   Past  18Sep2020  06Oct2020     5793636  SIR-F  1.64  0.001008  0.000216
# 4th   Past  07Oct2020  24Oct2020     5793636  SIR-F  1.01  0.001008  0.000216
# 5th   Past  25Oct2020  04Nov2020     5793636  SIR-F  2.19  0.000357  0.000403
# 6th   Past  05Nov2020  15Nov2020     5793636  SIR-F  1.07  0.000435  0.000185
# 7th   Past  16Nov2020  25Nov2020     5793636  SIR-F  1.12  0.001713  0.000095
# 8th   Past  26Nov2020  04Dec2020     5793636  SIR-F  1.20  0.000410  0.000362
# 9th   Past  05Dec2020  10Dec2020     5793636  SIR-F  1.99  0.001418  0.000054
# 10th  Past  11Dec2020  16Dec2020     5793636  SIR-F  2.39  0.000201  0.000273
# 11th  Past  17Dec2020  22Dec2020     5793636  SIR-F  1.60  0.000864  0.000368
# 12th  Past  23Dec2020  28Dec2020     5793636  SIR-F  0.77  0.002575  0.000301
# 13th  Past  29Dec2020  05Jan2021     5793636  SIR-F  0.65  0.004712  0.000521
# 14th  Past  06Jan2021  15Jan2021     5793636  SIR-F  0.63  0.018696  0.000101
# 15th  Past  16Jan2021  31Jan2021     5793636  SIR-F  0.48  0.037677  0.000109
# 16th  Past  01Feb2021  24Feb2021     5793636  SIR-F  0.75  0.001674  0.001216
#
#            rho     sigma   tau  1/beta [day]  1/alpha2 [day]  alpha1 [-]  \
# 0th   0.126678  0.030538  1440             7            4114       0.086
# 1st   0.056905  0.077720  1440            17            1785       0.036
# 2nd   0.085901  0.062733  1440            11            3927       0.001
# 3rd   0.086731  0.052607  1440            11            4624       0.001
# 4th   0.084857  0.083997  1440            11            4638       0.001
# 5th   0.098207  0.044511  1440            10            2484       0.000
# 6th   0.076459  0.071186  1440            13            5407       0.000
# 7th   0.090429  0.080450  1440            11           10568       0.002
# 8th   0.090240  0.074497  1440            11            2759       0.000
# 9th   0.110628  0.055408  1440             9           18407       0.001
# 10th  0.104835  0.043656  1440             9            3664       0.000
# 11th  0.076171  0.047158  1440            13            2716       0.001
# 12th  0.060046  0.077691  1440            16            3318       0.003
# 13th  0.065561  0.099132  1440            15            1919       0.005
# 14th  0.061490  0.095658  1440            16            9872       0.019
# 15th  0.053439  0.107867  1440            18            9157       0.038
# 16th  0.070116  0.091842  1440            14             822       0.002
#
#       1/gamma [day]     RMSLE  Trials       Runtime
# 0th              32  2.071002     817  1 min  0 sec
# 1st              12  0.242392     798  1 min  0 sec
# 2nd              15  0.148205     899  1 min  0 sec
# 3rd              19  0.063430     829  1 min  0 sec
# 4th              11  0.050941     818  1 min  0 sec
# 5th              22  0.022498     901  1 min  0 sec
# 6th              14  0.016198     609  0 min 40 sec
# 7th              12  0.010503     141  0 min 10 sec
# 8th              13  0.005133     487  0 min 30 sec
# 9th              18  0.010065     138  0 min 10 sec
# 10th             22  0.011021    1051  1 min  0 sec
# 11th             21  0.021636     819  1 min  0 sec
# 12th             12  0.008761     174  0 min 10 sec
# 13th             10  0.014519     184  0 min 10 sec
# 14th             10  0.025641     937  0 min 40 sec
# 15th              9  0.022044     179  0 min 10 sec
# 16th             10  0.062282     337  0 min 20 sec

# %%
snl.estimate_accuracy(phase="1st")

# %%
snl.get("Rt", phase="4th")
# Out:
# 1.01

# %%
_ = snl.history(target="Rt")

# %%
_ = snl.history("Infected")
